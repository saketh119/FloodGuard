# %% [markdown]
# # 03 Model Training
#
# Train and evaluate models only after preprocessing and feature selection are finalized.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Add the training pipeline here after the preprocessing notebook defines the final dataset.
